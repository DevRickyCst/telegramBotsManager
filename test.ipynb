# %%
from telegram import Bot
from telegram import ReactionType

# %%
client = Bot(token="6656641048:AAGqqzE2JZLazWx-0VxAjOVRbE6gaxlpvMs")

# %%
client.set_message_reaction(
    chat_id=-1001942228882,
    message_id=12,
    reaction=ReactionType.CUSTOM_EMOJI("👀")
)
